# %%
import boto3

bucket_name = 'dc-s3-1'
s3 = boto3.resource('s3')
s3.Bucket(bucket_name).upload_file('/0/test.jpg', 'test.jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-6cb5b390ea49> in <module>
#       3 bucket_name = 'dc-s3-1'
#       4 s3 = boto3.resource('s3')
# ----> 5 s3.Bucket(bucket_name).upload_file('/0/test.jpg', 'test.jpg')
#
# /usr/local/lib/python3.8/site-packages/boto3/s3/inject.py in bucket_upload_file(self, Filename, Key, ExtraArgs, Callback, Config)
#     205         transfer.
#     206     """
# --> 207     return self.meta.client.upload_file(
#     208         Filename=Filename, Bucket=self.name, Key=Key,
#     209         ExtraArgs=ExtraArgs, Callback=Callback, Config=Config)
#
# /usr/local/lib/python3.8/site-packages/boto3/s3/inject.py in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     127     """
#     128     with S3Transfer(self, Config) as transfer:
# --> 129         return transfer.upload_file(
# ...
